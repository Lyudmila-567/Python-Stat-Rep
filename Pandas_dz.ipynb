# %% [markdown]
# Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите, какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
datamov = pd.read_csv('movies.csv')
datamov.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
datarating = pd.read_csv('ratings.csv')
datarating.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
slice_rate5 = datarating[datarating.rating == 5.0]['movieId'].value_counts() #Вроде и так выводит по убыванию...
slice_rate5
# Out:
# 318      153
# 296      123
# 356      116
# 2571     109
# 260      104
#         ...
# 45672      1
# 2822       1
# 611        1
# 8807       1
# 83969      1
# Name: movieId, Length: 2954, dtype: int64

# %%
rate5_title = datamov[datamov.movieId == 318]['title']
rate5_title
# Out:
# 277    Shawshank Redemption, The (1994)
# Name: title, dtype: object

# %% [markdown]
# Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
import pandas as pd

# %%
datapower = pd.read_csv('power.csv')
datapower.head(10)
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1
# 5  Belgium  2011      25.0         1
# 6  Belgium  2010      22.0         1
# 7  Belgium  2009      45.0         1
# 8  Czechia  1998       1.0         1
# 9  Czechia  1995       7.0         1

# %%
datapower['country'].unique()
# Out:
# array(['Austria', 'Belgium', 'Czechia', 'Finland', 'France', 'Greece',
#        'Hungary', 'Italy', 'Korea, Republic of', 'Netherlands', 'Romania',
#        'Serbia', 'Slovakia', 'Ukraine', 'United Kingdom', 'United States',
#        'Brunei Darussalam', 'Bulgaria', 'Canada', 'Chile', 'Croatia',
#        'Iran (Islamic Rep. of)', 'Jordan', 'Lithuania', 'Mexico', 'Oman',
#        'Other Asia', 'Poland', 'Portugal', 'Spain', 'Sweden',
#        'Switzerland', 'T.F.Yug.Rep. Macedonia', 'Turkey', 'Uzbekistan',
#        'Argentina', 'Colombia', 'Germany', 'Norway', 'Australia',
#        'China, Macao SAR', 'Japan', 'Denmark', 'Ireland', 'Philippines',
#        'Bangladesh', 'Eritrea', 'Ethiopia', 'Lesotho', 'Nepal', 'Niger',
#        'Pakistan', 'Serbia and Montenegro', 'Tunisia', 'Botswana',
#        'Georgia', 'Republic of Moldova', 'Peru', 'South Africa',
#        'Iceland', 'Latvia', 'Luxembourg', 'Cuba', 'Kyrgyzstan',
# ...

# %%
filtered_countries = datapower[ (datapower['country']=='Lithuania') | (datapower['country']=='Latvia') | (datapower['country']=='Estonia')]
filtered_countries.head(20)       #Пробуем сделать выборку по странам
# Out:
#         country  year  quantity  category
# 373   Lithuania  2014      39.0         1
# 374   Lithuania  2013     192.0         1
# 375   Lithuania  2012     196.0         1
# 376   Lithuania  2011     171.0         1
# 377   Lithuania  2010     158.0         1
# 378   Lithuania  2009     158.0         1
# 379   Lithuania  2008     100.0         1
# 380   Lithuania  2007     105.0         1
# 956   Lithuania  2014       0.0         1
# 957   Lithuania  2013       0.0         1
# 958   Lithuania  2012       0.0         1
# 959   Lithuania  2011       0.0         1
# 960   Lithuania  2010       0.0         1
# 961   Lithuania  2009       3.0         1
# 962   Lithuania  2008       9.0         1
# 963   Lithuania  2007       1.0         1
# 1154  Lithuania  2014      -2.0         1
# 1155  Lithuania  2013      -1.0         1
# 1156  Lithuania  2012       3.0         1
# 1157  Lithuania  2011      -7.0         1

# %%
filtered_country = datapower[ (datapower['country'].isin(['Lithuania', 'Latvia', 'Estonia'])) & (datapower['category'].isin(['4', '12', '21'])) & (datapower['year'].isin(['2005', '2006', '2007', '2008', '2009', '2010'])) & (datapower['quantity'] >= 0)]
filtered_country.head(50)  #Добавляем сразу все фильтры
# Out:
#          country  year  quantity  category
# 10617    Estonia  2008       1.0         4
# 10618    Estonia  2007       0.0         4
# 10619    Estonia  2006       0.0         4
# 10620    Estonia  2005       1.0         4
# 11156  Lithuania  2008       1.0         4
# 11157  Lithuania  2007       0.0         4
# 11158  Lithuania  2006       1.0         4
# 11159  Lithuania  2005       1.0         4
# 12755    Estonia  2008       1.0         4
# 12756    Estonia  2007       0.0         4
# 12757    Estonia  2006       0.0         4
# 12758    Estonia  2005       1.0         4
# 13294  Lithuania  2008       1.0         4
# 13295  Lithuania  2007       0.0         4
# 13296  Lithuania  2006       1.0         4
# 13297  Lithuania  2005       1.0         4
# 14647     Latvia  2010       0.0         4
# 14648     Latvia  2009       0.0         4
# 14649     Latvia  2008       0.0         4
# 14650     Latvia  2007       0.0         4
# 15525    Estonia  2008       1.0         4
# ...

# %%
total_quant = filtered_country['quantity'].sum()
total_quant
# Out:
# 240580.0

# %% [markdown]
# Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
import pandas as pd

# %%
pd.read_html('https://finance.i.ua/')[0]
# Out:
#   Валюта        Покупка        Продажа            НБУ
# 0    USD  27.59730.0055  27.77470.0231  27.71840.0356
# 1    EUR  32.73310.0003  33.10770.0401  32.95020.0283
# 2    RUB   0.33470.0057   0.38180.0068   0.37400.0003
# 3    PLN   6.91470.2053   7.25570.0243   7.13250.0040

# %%
page_url = 'https://finance.i.ua/'
df = pd.read_html(page_url, attrs = {'class': 'table table-data -important'}, encoding='utf-8')
df1 = df[1]
print(df1)
# Out:
#   Валюта        Покупка        Продажа
# 0    USD  27.63980.0127  27.75320.0073
# 1    EUR  32.94060.0440  33.02370.0247
# 2    RUB   0.37100.0010   0.37610.0006
# 3    PLN   7.10240.0165   7.20090.0173
